# %%
pwd
# Out:
# '/Users/satyam.kumar/Desktop/NEWML/source'

# %%
# %run ./train.py default 10 30 plot
# Out:
# Train size: 3999 Test size: 999 4999
# Epoch 1/10
#  - 1s - loss: 0.5999 - mse: 0.5999 - mape: 92.0012
# Epoch 2/10
#  - 0s - loss: 0.4254 - mse: 0.4254 - mape: 76.5943
# Epoch 3/10
#  - 0s - loss: 0.2944 - mse: 0.2944 - mape: 62.5973
# Epoch 4/10
#  - 0s - loss: 0.1988 - mse: 0.1988 - mape: 50.1943
# Epoch 5/10
#  - 0s - loss: 0.1314 - mse: 0.1314 - mape: 39.1868
# Epoch 6/10
#  - 0s - loss: 0.0859 - mse: 0.0859 - mape: 29.7264
# Epoch 7/10
#  - 0s - loss: 0.0567 - mse: 0.0567 - mape: 21.8358
# Epoch 8/10
#  - 0s - loss: 0.0390 - mse: 0.0390 - mape: 15.8926
# Epoch 9/10
#  - 0s - loss: 0.0288 - mse: 0.0288 - mape: 12.1501
# Epoch 10/10
#  - 0s - loss: 0.0233 - mse: 0.0233 - mape: 10.6086
#
# Model and its history saved in models/model-default-10-30*
# Scores for default (epochs=10, batch_size=30)
# Train Score: RMSE: 0 MAPE: 10%
# Test Score: RMSE: 0 MAPE: 13%
# Train size: 3999 Test size: 999 4999
# Baseline Training Score: RMSE: 0
# Baseline Test Score: RMSE: 0

# %%
# %run ./predict.py default 10 30
# Out:
# Model loaded!
# Prediction from Sep 06, 2019 based on 1
# Prediction for Sep 06, 2019next is 1 +/- 0

# %%
# %run ./train.py default 40 20 plot
# Out:
# Train size: 3999 Test size: 999 4999
# Epoch 1/40
#  - 1s - loss: 0.0961 - mse: 0.0961 - mape: 32.5623
# Epoch 2/40
#  - 0s - loss: 0.0037 - mse: 0.0037 - mape: 4.7887
# Epoch 3/40
#  - 0s - loss: 0.0024 - mse: 0.0024 - mape: 4.5935
# Epoch 4/40
#  - 0s - loss: 0.0023 - mse: 0.0023 - mape: 4.4922
# Epoch 5/40
#  - 0s - loss: 0.0022 - mse: 0.0022 - mape: 4.3321
# Epoch 6/40
#  - 0s - loss: 0.0020 - mse: 0.0020 - mape: 4.1662
# Epoch 7/40
#  - 0s - loss: 0.0018 - mse: 0.0018 - mape: 4.0155
# Epoch 8/40
#  - 0s - loss: 0.0016 - mse: 0.0016 - mape: 3.7525
# Epoch 9/40
#  - 0s - loss: 0.0014 - mse: 0.0014 - mape: 3.5669
# Epoch 10/40
#  - 0s - loss: 0.0013 - mse: 0.0013 - mape: 3.2910
# Epoch 11/40
#  - 0s - loss: 0.0011 - mse: 0.0011 - mape: 3.0279
# Epoch 12/40
#  - 1s - loss: 8.7795e-04 - mse: 8.7795e-04 - mape: 2.7678
# Epoch 13/40
#  - 0s - loss: 7.0758e-04 - mse: 7.0758e-04 - mape: 2.4820
# Epoch 14/40
#  - 0s - loss: 5.5522e-04 - mse: 5.5522e-04 - mape: 2.1853
# Epoch 15/40
# ...

# %%
# %run ./predict.py default 40 20
# Out:
# Model loaded!
# Prediction from Sep 06, 2019 based on 1
# Prediction for Sep 06, 2019next is 1 +/- 0
